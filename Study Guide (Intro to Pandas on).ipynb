# %% [markdown]
# # Lecture 9: Intro to Pandas

# %% [markdown]
# Pandas has two core types: DataFrames and Series

# %% [markdown]
# #### Reminders/Review:

# %% [markdown]
# - Objects and methods.
#
# - Recall that we apply the method justdoit to the object x with x.justdoit().
#
#
# - Help. We get help in Spyder from both the IPython console and the Object inspector. For the hypothetical x.justdoit, we would type x.justdoit? in the IPython console or x.justdoit in the Object inspector.
#
#
# - Data structures. That's the term we use for specific organizations of data. Examples are lists, tuples, and dictionaries. Each has a specific structure and a set of methods we can apply. List are (ordered) collections of objects between square brackets: numberlist = [1, -5, 2]. Dictionaries are (unordered) pairs of items between curly brackets: namedict = {'Dave': 'Backus', 'Chase': 'Coleman'}. The first item in each pair is the "key," the second is the "value.""
#
#
# - Integers, floats, and strings. Three common types of data.
#
#
# - Function returns. We refer to the output of a function as its return. We would say, for example, that the function type(x) returns the type of the input object x. We capture the return with an assignment: xtype = type(x).
#
#
# - Packages. Packages are collections of tools -- functions and types/methods -- that extend Python's capabilities. We import a package using an import (e.g. import pandas) statement or some combination of import, from, and as (e.g. import pandas as pd or from pandas import DataFrame).

# %% [markdown]
# #### DataFrames

# %% [markdown]
# A DataFrame is similar to an excel sheet. Always import Pandas first!! import pandas as pd

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %%
import pandas as pd

# %%
df = pd.DataFrame({"GDP": [5974.7, 10031.0, 14681.1],
                   "CPI": [127.5, 169.3, 217.488],
                   "Year": [1990, 2000, 2010],
                   "Country": ["US", "US", "US"]})

# Input is a dictionary with lists; column headers and values

# %%
df
# Out:
#        GDP      CPI  Year Country
# 0   5974.7  127.500  1990      US
# 1  10031.0  169.300  2000      US
# 2  14681.1  217.488  2010      US

# %% [markdown]
# Column names or labels-- are the keys from the dictionary. They are also referred to as the variables. The row numbers are the index. The data within the index and columns are the values.

# %%
# In excel -- Rows and columns; put clumn headers in the first row
# This is very similar; but in the case of a data frame there are indices outside the rows and columns
# Always have NAMES -- for all columns and rows

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.T
# Out:
#               0      1        2
# GDP      5974.7  10031  14681.1
# CPI       127.5  169.3  217.488
# Year       1990   2000     2010
# Country      US     US       US

# %% [markdown]
# ### Series:

# %%
df['CPI'] # Selecting a column also results in selecting its index
# Out:
# 0    127.500
# 1    169.300
# 2    217.488
# Name: CPI, dtype: float64

# %%
type(df['CPI'])
# Out:
# pandas.core.series.Series

# %%
# A series is just one column of a dataframe
# Two objects of pandas: Dataframes and Series! Similar to how the object of Numpy are arrays

# %% [markdown]
# Selecting a Variable from a DataFrame gives the output of a series.
#
# - A series is essentially a DataFrame with a single variable or column
# - Series are useful because we can do addition, subtraction, multiplication, and division with them.

# %%
print(df["GDP"] + df["GDP"])
print(df["GDP"] - df["GDP"])
print(df["GDP"] / df["CPI"])
print(df["CPI"] * df["CPI"])
# Out:
# 0    11949.4
# 1    20062.0
# 2    29362.2
# Name: GDP, dtype: float64
# 0    0.0
# 1    0.0
# 2    0.0
# Name: GDP, dtype: float64
# 0    46.860392
# 1    59.249852
# 2    67.503035
# dtype: float64
# 0    16256.250000
# 1    28662.490000
# 2    47301.030144
# Name: CPI, dtype: float64

# %% [markdown]
# We can also do operations with on a Series with Integers and Floats:

# %%
print(df["GDP"] / 10000)
# Out:
# 0    0.59747
# 1    1.00310
# 2    1.46811
# Name: GDP, dtype: float64

# %% [markdown]
# ### Attributes vs. Methods

# %% [markdown]
# Attributes do not require parentheses (something that belongs to the object inherently); just retrieving information about that object.

# %%
df.columns #
# Out:
# Index(['GDP', 'CPI', 'Year', 'Country'], dtype='object')

# %%
df.describe() # Get a bunch of summary statistics
# Out:
#                 GDP         CPI    Year
# count      3.000000    3.000000     3.0
# mean   10228.933333  171.429333  2000.0
# std     4356.573590   45.031773    10.0
# min     5974.700000  127.500000  1990.0
# 25%     8002.850000  148.400000  1995.0
# 50%    10031.000000  169.300000  2000.0
# 75%    12356.050000  193.394000  2005.0
# max    14681.100000  217.488000  2010.0

# %% [markdown]
# Need parenthesis since this is a method!
#
# Functions, methods, and attributes
#
# Function Example:

# %%
sum(df['GDP'])
# Out:
# 30686.800000000003

# %% [markdown]
# Method Example:

# %%
df['GDP'].sum()
# Out:
# 30686.800000000003

# %% [markdown]
# A method written specifically for Pandas; only works on series and dataframes
#
# Work the same way-- but methods are written for specific types of objects
# Attributes just tell you something about the object you are calling

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
# Appending is a method -- being applied to the list

# %% [markdown]
# Characteristics of dataframes-- getting the dimensions by rows, columns:

# %%
df.shape
# Out:
# (3, 4)

# %%
df
# Out:
#        GDP      CPI  Year Country
# 0   5974.7  127.500  1990      US
# 1  10031.0  169.300  2000      US
# 2  14681.1  217.488  2010      US

# %% [markdown]
# #### To extrat rows and columns:

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.index.tolist()
# Out:
# [0, 1, 2]

# %% [markdown]
# In the case above, the index is not part of the original data, so Pandas inserted a counter which starts at zero.

# %%
df.columns
# Out:
# Index(['GDP', 'CPI', 'Year', 'Country'], dtype='object')

# %%
df.dtypes
# Out:
# GDP        float64
# CPI        float64
# Year         int64
# Country     object
# dtype: object

# %% [markdown]
# Object is the name pandas gives to things it can't turn into numbers (ie strings in this case)

# %% [markdown]
# Every column has a specific datatype:
# Country is object-- if it is not numerical, it is an object
#     ie. object means string variables

# %%
df.T.dtypes # Chained commands or assignments-- lots of things happening within one linebb
# Out:
# 0    object
# 1    object
# 2    object
# dtype: object

# %% [markdown]
# Same as df.trasnpose() -- just a shortened version

# %% [markdown]
# Transposing it causes everything to be objects. Mixes are stored as objects. Object is a catch all in pandas

# %%
df.describe()['GDP'].mean()
# Out:
# 8204.275865391532

# %% [markdown]
# Gives us a Series with GDP
#
# With mean-- gives us a number

# %%
df['Country'].value_counts()
# Out:
# US    3
# Name: Country, dtype: int64

# %% [markdown]
# Very handy with categorical data!

# %%
df
# Out:
#        GDP      CPI  Year Country
# 0   5974.7  127.500  1990      US
# 1  10031.0  169.300  2000      US
# 2  14681.1  217.488  2010      US

# %% [markdown]
# #### Creating a New Variable

# %% [markdown]
# Create real GDP: GDP/CPI

# %%
df['rgdp'] = df['GDP']/df['CPI'] # Adds a new column

# %%
df
# Out:
#        GDP      CPI  Year Country       rgdp
# 0   5974.7  127.500  1990      US  46.860392
# 1  10031.0  169.300  2000      US  59.249852
# 2  14681.1  217.488  2010      US  67.503035

# %%
df[['Year','GDP','rgdp']] #Brackets are taking a slice of the dataframe
# Out:
#    Year      GDP       rgdp
# 0  1990   5974.7  46.860392
# 1  2000  10031.0  59.249852
# 2  2010  14681.1  67.503035

# %% [markdown]
# Still a dataframe type! Multiple columns so not a series

# %%
df.columns
# Out:
# Index(['GDP', 'CPI', 'Year', 'Country', 'rgdp'], dtype='object')

# %%
df[['GDP', 'CPI', 'Year', 'Country', 'rgdp']] # Moving items in list around moves columns
# Out:
#        GDP      CPI  Year Country       rgdp
# 0   5974.7  127.500  1990      US  46.860392
# 1  10031.0  169.300  2000      US  59.249852
# 2  14681.1  217.488  2010      US  67.503035

# %% [markdown]
# Digression: common syntax errors:
#
# - df[GDP] is commonly referred to as df.GDP. This doesn't always work.
# - Integer Variable names-- ie 2011 would be df[2011] without quotes. If you aren't sure what type of variable the labels are in, use df.columns to check and see whether they have quotes.

# %%
df.loc[(1,2),:] # A way to slice more cleanly; primary way to filter
# Out:
#        GDP      CPI  Year Country       rgdp
# 1  10031.0  169.300  2000      US  59.249852
# 2  14681.1  217.488  2010      US  67.503035

# %%
df.drop('CPI',1) #axis = 1 refers to columns and axis = 0 refers to rows
# Out:
#        GDP  Year Country       rgdp
# 0   5974.7  1990      US  46.860392
# 1  10031.0  2000      US  59.249852
# 2  14681.1  2010      US  67.503035

# %%
df2 = df.drop('CPI',1)

# %% [markdown]
# CPI is still in it because it doesn't change the original dataframe

# %%
df2
# Out:
#        GDP  Year Country       rgdp
# 0   5974.7  1990      US  46.860392
# 1  10031.0  2000      US  59.249852
# 2  14681.1  2010      US  67.503035

# %%
df
# Out:
#        GDP      CPI  Year Country       rgdp
# 0   5974.7  127.500  1990      US  46.860392
# 1  10031.0  169.300  2000      US  59.249852
# 2  14681.1  217.488  2010      US  67.503035

# %%
# Data Frames: can feed in dictionaries, Numpy array

pd.DataFrame(['5','cat'])
# Out:
#      0
# 0    5
# 1  cat

# %% [markdown]
# Can pass in a list

# %% [markdown]
# ### Convention or Preference on Style

# %% [markdown]
# Column names should not ever really be upper case

# %%
df
# Out:
#        gdp      cpi  year country       rgdp
# 0   5974.7  127.500  1990      US  46.860392
# 1  10031.0  169.300  2000      US  59.249852
# 2  14681.1  217.488  2010      US  67.503035

# %% [markdown]
# How to turn all column headers to lower case

# %%
df.columns.lower() #.lower only works on string objects
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-44d53033d1ad> in <module>()
# ----> 1 df.columns.lower() #.lower only works on string objects
#
# AttributeError: 'Index' object has no attribute 'lower'

# %%
str(df.columns)
# Out:
# "Index(['GDP', 'CPI', 'Year', 'Country', 'rgdp'], dtype='object')"

# %%
df.columns
# Out:
# Index(['GDP', 'CPI', 'Year', 'Country', 'rgdp'], dtype='object')

# %%
str(df.columns).lower()
# Out:
# "index(['gdp', 'cpi', 'year', 'country', 'rgdp'], dtype='object')"

# %% [markdown]
# ## Renaming variables

# %%
df.rename(columns={'GDP':'gdp'}) #rename function
# Out:
#        gdp      CPI  Year Country       rgdp
# 0   5974.7  127.500  1990      US  46.860392
# 1  10031.0  169.300  2000      US  59.249852
# 2  14681.1  217.488  2010      US  67.503035

# %% [markdown]
# Loop to go through all the columns to rename them lower cased

# %%
# for i in df.columns:
df.columns = [i.lower() for i in df.columns] #clever use of a list comprehension

# %%
df
# Out:
#        gdp      cpi  year country       rgdp
# 0   5974.7  127.500  1990      US  46.860392
# 1  10031.0  169.300  2000      US  59.249852
# 2  14681.1  217.488  2010      US  67.503035

# %%
for i in df2.columns: # iterating through the columns; for every column, redefining the dataframe
    df2 = df2.rename(columns={i:i.lower()})

# %%
df2
# Out:
#        gdp  year country       rgdp
# 0   5974.7  1990      US  46.860392
# 1  10031.0  2000      US  59.249852
# 2  14681.1  2010      US  67.503035

# %% [markdown]
# This is creating a new dataframe with a new column named every time

# %% [markdown]
# ### Top and Bottom of a DataFrame

# %%
h = df.head(2) 
print(type(h))
print(h)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#        gdp    cpi  year country       rgdp
# 0   5974.7  127.5  1990      US  46.860392
# 1  10031.0  169.3  2000      US  59.249852

# %%
df.tail(2) ## Bottom 2 entries
# Out:
#        gdp      cpi  year country       rgdp
# 1  10031.0  169.300  2000      US  59.249852
# 2  14681.1  217.488  2010      US  67.503035

# %% [markdown]
# #### Setting Index

# %%
df = df.set_index('year')

# %%
df
# Out:
#           gdp      cpi country       rgdp
# year
# 1990   5974.7  127.500      US  46.860392
# 2000  10031.0  169.300      US  59.249852
# 2010  14681.1  217.488      US  67.503035

# %%
df_reset = df.reset_index() # Reversal of setting index

# %% [markdown]
# #### Statistics

# %%
df.mean()
df.std()
df.describe() # See below: gives summary statistics
# Out:
#                 gdp         cpi    year       rgdp
# count      3.000000    3.000000     3.0   3.000000
# mean   10228.933333  171.429333  2000.0  57.871093
# std     4356.573590   45.031773    10.0  10.390159
# min     5974.700000  127.500000  1990.0  46.860392
# 25%     8002.850000  148.400000  1995.0  53.055122
# 50%    10031.000000  169.300000  2000.0  59.249852
# 75%    12356.050000  193.394000  2005.0  63.376443
# max    14681.100000  217.488000  2010.0  67.503035

# %% [markdown]
# #### Plotting

# %%
df.plot()

# %% [markdown]
# How to save this dataframe somewhere:

# %%
# Index should be unique by oberservation (Every row is a different year; so have the year be the labels of the row)

# %%
df.to_excel('/Users/hadley/Desktop/df_test_0.xlsx') # Put in file path-- best thing to do is to copy the file path in

# %% [markdown]
# Can also do df.to_csv()

# %%
df_clip = pd.read_clipboard() # read fromthe clipboard and write to it. 
df.to_clipboard() # Goes the other way-- copies a DataFrame to the clipboard

# %%
df3 = pd.read_excel('/Users/hadley/Desktop/df_test_0.xlsx')

# %%
df3
# Out:
#    year      gdp      cpi country       rgdp
# 0  1990   5974.7  127.500      US  46.860392
# 1  2000  10031.0  169.300      US  59.249852
# 2  2010  14681.1  217.488      US  67.503035

# %% [markdown]
# Excel doesn't have a concept of year as index!
#
# Excel has a lot more functionality-- meaning it is a lot slower to read in a file
#
# CSV takes no time because it is just a text file; no functionality, only raw data with comma separated values
#
# No formating problems in excel because there are rigid guidelines; but excel is not really feasible to use most of the time

# %%
df.to_pickle('/Users/hadley/Desktop/df_test_0.pkl')

# %%
df4 = pd.read_pickle('/Users/hadley/Desktop/df_test_0.pkl')

# %%
df4
# Out:
#           gdp      cpi country       rgdp
# year
# 1990   5974.7  127.500      US  46.860392
# 2000  10031.0  169.300      US  59.249852
# 2010  14681.1  217.488      US  67.503035

# %% [markdown]
# ## Data Input

# %%
import pandas as pd
url1 = 'https://raw.githubusercontent.com/NYUDataBootcamp'
url2 = '/Materials/master/Data/test.csv'
url  = url1 + url2        # location of file
                            # Splitting Url into 1 and 2
df = pd.read_csv(url)     # read file and assign it to df

# %%
url
# Out:
# 'https://raw.githubusercontent.com/NYUDataBootcamp/Materials/master/Data/test.csv'

# %% [markdown]
# People are picky about reading everything on one line; not a big deal why it is split

# %%
df
# Out:
#       name  x1  x2   x3
# 0     Dave   1   2  3.5
# 1    Chase   4   3  4.3
# 2  Spencer   5   6  7.8

# %% [markdown]
# To check what is in the df being read in, check its contents with this statement:

# %%
print('\n', df)
# Out:
#        name  x1  x2   x3
# 0     Dave   1   2  3.5
# 1    Chase   4   3  4.3
# 2  Spencer   5   6  7.8

# %% [markdown]
# The '\n' tells the print function to start printing on a new line, making the output look better.

# %%
dfalt = pd.read_csv(url, nrows=2)
print('\n', dfalt)
# Out:
#      name  x1  x2   x3
# 0   Dave   1   2  3.5
# 1  Chase   4   3  4.3

# %% [markdown]
# Tells it to read in the first two rows of the file.

# %%
pd.read_csv(url, na_values=[1])
# Out:
#       name   x1  x2   x3
# 0     Dave  NaN   2  3.5
# 1    Chase  4.0   3  4.3
# 2  Spencer  5.0   6  7.8

# %% [markdown]
# Nan = not a number
#
# This is not very practical currently, but is useful as we deal with incomplete and messy data.

# %%
df.mean
# Out:
# <bound method DataFrame.mean of       name  x1  x2   x3
# 0     Dave   1   2  3.5
# 1    Chase   4   3  4.3
# 2  Spencer   5   6  7.8>

# %% [markdown]
# ### Read in data from an API

# %% [markdown]
# Don't see raw data, see it post-project
# Won't be using APIs much

# %%
url = 'https://www.rug.nl/ggdc/docs/pwt90.xlsx'
pwt = pd.read_excel(url, sheetname='Data')
# Out:
# /anaconda3/lib/python3.7/site-packages/pandas/io/excel.py:329: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   **kwds)

# %%
pwt
# Out:
#       countrycode   country   currency_unit  year         rgdpe         rgdpo  \
# 0             ABW     Aruba  Aruban Guilder  1950           NaN           NaN
# 1             ABW     Aruba  Aruban Guilder  1951           NaN           NaN
# 2             ABW     Aruba  Aruban Guilder  1952           NaN           NaN
# 3             ABW     Aruba  Aruban Guilder  1953           NaN           NaN
# 4             ABW     Aruba  Aruban Guilder  1954           NaN           NaN
# 5             ABW     Aruba  Aruban Guilder  1955           NaN           NaN
# 6             ABW     Aruba  Aruban Guilder  1956           NaN           NaN
# 7             ABW     Aruba  Aruban Guilder  1957           NaN           NaN
# 8             ABW     Aruba  Aruban Guilder  1958           NaN           NaN
# 9             ABW     Aruba  Aruban Guilder  1959           NaN           NaN
# 10            ABW     Aruba  Aruban Guilder  1960           NaN           NaN
# ...

# %%
pwt.shape
# Out:
# (11830, 47)

# %%
pwt.columns
# Out:
# Index(['countrycode', 'country', 'currency_unit', 'year', 'rgdpe', 'rgdpo',
#        'pop', 'emp', 'avh', 'hc', 'ccon', 'cda', 'cgdpe', 'cgdpo', 'ck',
#        'ctfp', 'cwtfp', 'rgdpna', 'rconna', 'rdana', 'rkna', 'rtfpna',
#        'rwtfpna', 'labsh', 'delta', 'xr', 'pl_con', 'pl_da', 'pl_gdpo',
#        'i_cig', 'i_xm', 'i_xr', 'i_outlier', 'cor_exp', 'statcap', 'csh_c',
#        'csh_i', 'csh_g', 'csh_x', 'csh_m', 'csh_r', 'pl_c', 'pl_i', 'pl_g',
#        'pl_x', 'pl_m', 'pl_k'],
#       dtype='object')

# %%
url1 = 'https://raw.githubusercontent.com/fivethirtyeight/data/master/'
url2 = 'college-majors/recent-grads.csv'
url = url1 + url2
df538 = pd.read_csv(url)

# %%
df538
# Out:
#      Rank  Major_code                                          Major  \
# 0       1        2419                          PETROLEUM ENGINEERING
# 1       2        2416                 MINING AND MINERAL ENGINEERING
# 2       3        2415                      METALLURGICAL ENGINEERING
# 3       4        2417      NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4       5        2405                           CHEMICAL ENGINEERING
# 5       6        2418                            NUCLEAR ENGINEERING
# 6       7        6202                              ACTUARIAL SCIENCE
# 7       8        5001                     ASTRONOMY AND ASTROPHYSICS
# 8       9        2414                         MECHANICAL ENGINEERING
# 9      10        2408                         ELECTRICAL ENGINEERING
# 10     11        2407                           COMPUTER ENGINEERING
# 11     12        2401                          AEROSPACE ENGINEERING
# 12     13        2404                         BIOMEDICAL ENGINEERING
# ...

# %% [markdown]
# Reading in on Mac: NOTE DIFFERENT SLASHES
#
# /Users/userid/Data_Bootcamp/test.csv
#
# Reading in on PC:
#
# C:\Users\userid\Documents\Data_Bootcamp\test.csv

# %% [markdown]
# To find paths:

# %% [markdown]
# - Windows.  Type the name of the file in the Windows search box or use Windows Explorer.
#
# - Mac OS.  We select (but not open) the file and do "command-i" to get the file's information window.  From the window, we copy the path that follows "Where:."  It looks like we're copying arrows, but they turn into slashes when we paste the path.

# %%
# In Windows, we take the complete path and -- this is important -- change all the backslashes \ to either double backslashes \\ or forward slashes /.  (Don't ask.)  Then we read the file from the path, just as we read it from a url earlier:

path = 'C:\\Users\\userid\\Documents\\Data_Bootcamp\\test.csv'
df = read_csv(path)

#In Mac OS we don't need to change the slashes:

path = '/Users/userid/Data_Bootcamp/test.csv'
df = read_csv(path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-205187781efd> in <module>()
#       2
#       3 path = 'C:\\Users\\userid\\Documents\\Data_Bootcamp\\test.csv'
# ----> 4 df = read_csv(path)
#       5
#       6 #In Mac OS we don't need to change the slashes:
#
# NameError: name 'read_csv' is not defined

# %% [markdown]
# ### Resources

# %% [markdown]
# We've covered a lot of ground, but if you're looking for more we suggest:
#
# On Pandas:  Chris Moffitt's Practical Business Python blog has a good series on Pandas from the perspective of an Excel user.  For a more concise summary, try Quandl's cheatsheet.
# On data:  See the list of data sources on the course website.
# On backslashes (and other obscure characters in code):  xkcd.

# %% [markdown]
# http://pbpython.com/archives.html
#
# https://s3.amazonaws.com/quandl-static-content/Documents/Quandl+-+Pandas%2C+SciPy%2C+NumPy+Cheat+Sheet.pdf
#
# https://xkcd.com/1638/

# %% [markdown]
# # Lecture 10: Python Graphics-- Matplotlib Fundamentals

# %%
import sys                             # system module
import pandas as pd                    # data package
import matplotlib as mpl               # graphics package
import matplotlib.pyplot as plt         # pyplot module
import datetime as dt                  # date and time module

# check versions (overkill, but why not?)
print('Python version:', sys.version)
print('Pandas version: ', pd.__version__)
print('Matplotlib version: ', mpl.__version__)
print('Today: ', dt.date.today())

# %% [markdown]
# This code imports all necessary packages and checks the versions and prints the dates.

# %%
import pandas as pd
# %matplotlib inline

# %%
gdp  = [13271.1, 13773.5, 14234.2, 14613.8, 14873.7, 14830.4, 14418.7,
        14783.8, 15020.6, 15369.2, 15710.3]
pce  = [8867.6, 9208.2, 9531.8, 9821.7, 10041.6, 10007.2, 9847.0, 10036.3,
        10263.5, 10449.7, 10699.7]
year = list(range(2003,2014))        # use range for years 2003-2013

# Note that we set the index
us = pd.DataFrame({'gdp': gdp, 'pce': pce}, index=year)

# %% [markdown]
# ### Two Approaches to Graphics in Matplotlib

# %% [markdown]
# 1. Apply plot methods to dataframes
#
# 2. Create figures and objects and apply methods to them

# %% [markdown]
# ### Approach 1

# %%
us.plot() #line plot

# %%
us['gdp'].plot() #single line plot

# %%
us.plot(y="gdp") #Same plot as above!

# %%
us.plot(kind='bar') #bar chart

# %%
us.plot.scatter('gdp', 'pce') #scatterplot-- must specify x and y (GDP and PCE respectively in this example)

# %%
us.plot() #line plot
kind='area'
subplots=True
sharey=True
figsize=(3,6)
ylim=(0,16000)

# %%
ff.plot(kind='hist',         # histogram
        bins=20,             # 20 bins
        subplots=True)       # two separate subplots
# Histogram-- I did not run this since the code would not import properly

# %% [markdown]
# ### Approach 2

# %%
import matplotlib.pyplot as plt  # import pyplot module
fig, ax = plt.subplots()         # create fig and ax objects

# %% [markdown]
# Note that we're using the pyplot function subplots(), which creates the objects fig and ax on the left. The subplot() function produces a blank figure, which is displayed in the Jupyter notebook. The names fig and ax can be anything, but these choices are standard.

# %% [markdown]
# - fig is a blank canvas for creating a figure.
# - ax is everything in it:  axes, labels, lines or bars, legend, and so on.

# %% [markdown]
# #### Creating Graphs

# %%
fig, axe = plt.subplots()        # create axis object axe
us.plot(ax=ax)                  # ax= looks for axis object, axe is it

# %% [markdown]
# us['gdp'].plot()                   # Approach #1
#
#
# plt.plot(us.index, us['gdp'])      # Approach #2
#
#
# fig, ax = plt.subplots()           # Approach #3
# us['gdp'].plot(ax=ax)

# %% [markdown]
# Which one should we use? Use Approach #3. Really. This is a case where choice is confusing.

# %% [markdown]
# #### When data isn't coming in properly (Greenwich Data)

# %% [markdown]
# unicode decode error => google it => go to stack overflow =>
# There is text written in certain ways
# Many different encodings
#
# From SQL, defaulting coding is latin-1 : often have to change the encoding
# In that line => there were 16 columns rather than 15 (probably an extra comma), not a huge deale to skip a line

# %%
url1 = 'https://raw.githubusercontent.com/fivethirtyeight/data/master/'
url2 = 'college-majors/recent-grads.csv'
url = url1 + url2
df538 = pd.read_csv(url)

# %%
df538
# Out:
#      Rank  Major_code                                          Major  \
# 0       1        2419                          PETROLEUM ENGINEERING
# 1       2        2416                 MINING AND MINERAL ENGINEERING
# 2       3        2415                      METALLURGICAL ENGINEERING
# 3       4        2417      NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4       5        2405                           CHEMICAL ENGINEERING
# 5       6        2418                            NUCLEAR ENGINEERING
# 6       7        6202                              ACTUARIAL SCIENCE
# 7       8        5001                     ASTRONOMY AND ASTROPHYSICS
# 8       9        2414                         MECHANICAL ENGINEERING
# 9      10        2408                         ELECTRICAL ENGINEERING
# 10     11        2407                           COMPUTER ENGINEERING
# 11     12        2401                          AEROSPACE ENGINEERING
# 12     13        2404                         BIOMEDICAL ENGINEERING
# ...

# %%
df538['ShareWomen'].describe()
# Out:
# count    172.000000
# mean       0.522223
# std        0.231205
# min        0.000000
# 25%        0.336026
# 50%        0.534024
# 75%        0.703299
# max        0.968954
# Name: ShareWomen, dtype: float64

# %%
df538['Women'].sum()/df538['Total'].sum()
# Out:
# 0.5752254914382808

# %%
df538['Median'].mean()
# Out:
# 40151.4450867052

# %% [markdown]
# Can't just sum across columns => have to make a weighted average

# %% [markdown]
# Producing aggregates and summary statistics is problematic to derive from aggregate data (which most data we use is)

# %% [markdown]
# Sumproduct (between thing we want to see the aggregate for and )/sum of the weighting variable

# %% [markdown]
# 1. Create a new variable

# %%
df538['sumproduct_median_total']=df538['Total']*df538['Median']

# %%
df538['sumproduct_median_total'].sum()/df538['Total'].sum()
# Out:
# 38115.56572441533

# %% [markdown]
# The average salary is LOWER => meaning the correlation between the count of people in the major and the salary are NEGATIVE. People are more likely to go into fields with lower than average salaries than higher than average.

# %%
df538['Major_category'].value_counts()
# Out:
# Engineering                            29
# Education                              16
# Humanities & Liberal Arts              15
# Biology & Life Science                 14
# Business                               13
# Health                                 12
# Computers & Mathematics                11
# Physical Sciences                      10
# Agriculture & Natural Resources        10
# Social Science                          9
# Psychology & Social Work                9
# Arts                                    8
# Industrial Arts & Consumer Services     7
# Law & Public Policy                     5
# Communications & Journalism             4
# Interdisciplinary                       1
# Name: Major_category, dtype: int64

# %%
df538['Major_category'].value_counts(normalize= True)#To change into percentages
# Out:
# Engineering                            0.167630
# Education                              0.092486
# Humanities & Liberal Arts              0.086705
# Biology & Life Science                 0.080925
# Business                               0.075145
# Health                                 0.069364
# Computers & Mathematics                0.063584
# Physical Sciences                      0.057803
# Agriculture & Natural Resources        0.057803
# Social Science                         0.052023
# Psychology & Social Work               0.052023
# Arts                                   0.046243
# Industrial Arts & Consumer Services    0.040462
# Law & Public Policy                    0.028902
# Communications & Journalism            0.023121
# Interdisciplinary                      0.005780
# Name: Major_category, dtype: float64

# %% [markdown]
# ### Sumplots

# %%
df = pd.DataFrame({"GDP": [5974.7, 10031.0, 14681.1],
                   "CPI": [127.5, 169.3, 217.488],
                   "Year": [1990, 2000, 2010],
                   "Country": ["US", "US", "US"]})
print(df)
# Out:
#        GDP      CPI  Year Country
# 0   5974.7  127.500  1990      US
# 1  10031.0  169.300  2000      US
# 2  14681.1  217.488  2010      US

# %%
df = df.set_index('Year')

# %%
df['rgdp']=df['GDP']/df['CPI']

# %%
df['GDP'].plot()

# %%
df['rgdp'].plot()

# %%
df.plot()

# %% [markdown]
# Doesn't make sense => on different scales

# %%
df.plot?

# %% [markdown]
# Signature:      df.plot(x=None, y=None, kind='line', ax=None, subplots=False, sharex=None, sharey=False, layout=None, figsize=None, use_index=True, title=None, grid=None, legend=True, style=None, logx=False, logy=False, loglog=False, xticks=None, yticks=None, xlim=None, ylim=None, rot=None, fontsize=None, colormap=None, table=False, yerr=None, xerr=None, secondary_y=False, sort_columns=False, **kwds)
# Type:           FramePlotMethods
# String form:    <pandas.plotting._core.FramePlotMethods object at 0x114dc02e8>
# File:           /anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py
# Docstring:
# DataFrame plotting accessor and method
#
# Examples
# --------
# >>> df.plot.line()
# >>> df.plot.scatter('x', 'y')
# >>> df.plot.hexbin()
#
# These plotting methods can also be accessed by calling the accessor as a
# method with the ``kind`` argument:
# ``df.plot(kind='line')`` is equivalent to ``df.plot.line()``
# Call docstring:
# Make plots of DataFrame using matplotlib / pylab.
#
# *New in version 0.17.0:* Each plot kind has a corresponding method on the
# ``DataFrame.plot`` accessor:
# ``df.plot(kind='line')`` is equivalent to
# ``df.plot.line()``.
#
# Parameters
# ----------
# data : DataFrame
#
# x : label or position, default None
#
# y : label, position or list of label, positions, default None
#     Allows plotting of one column versus another
#
# kind : str
#
#     - 'line' : line plot (default)
#     - 'bar' : vertical bar plot
#     - 'barh' : horizontal bar plot
#     - 'hist' : histogram
#     - 'box' : boxplot
#     - 'kde' : Kernel Density Estimation plot
#     - 'density' : same as 'kde'
#     - 'area' : area plot
#     - 'pie' : pie plot
#     - 'scatter' : scatter plot
#     - 'hexbin' : hexbin plot
#
# ax : matplotlib axes object, default None
#
# subplots : boolean, default False
#     Make separate subplots for each column
#
# sharex : boolean, default True if ax is None else False
#     In case subplots=True, share x axis and set some x axis labels to
#     invisible; defaults to True if ax is None otherwise False if an ax
#     is passed in; Be aware, that passing in both an ax and sharex=True
#     will alter all x axis labels for all axis in a figure!
#
# sharey : boolean, default False
#     In case subplots=True, share y axis and set some y axis labels to
#     invisible
#
# layout : tuple (optional)
#     (rows, columns) for the layout of subplots
#
# figsize : a tuple (width, height) in inches
#
# use_index : boolean, default True
#     Use index as ticks for x axis
#
# title : string or list
#     Title to use for the plot. If a string is passed, print the string at
#     the top of the figure. If a list is passed and `subplots` is True,
#     print each item in the list above the corresponding subplot.
#
# grid : boolean, default None (matlab style default)
#     Axis grid lines
#
# legend : False/True/'reverse'
#     Place legend on axis subplots
#
# style : list or dict
#     matplotlib line style per column
#
# logx : boolean, default False
#     Use log scaling on x axis
#
# logy : boolean, default False
#     Use log scaling on y axis
#
# loglog : boolean, default False
#     Use log scaling on both x and y axes
#
# xticks : sequence
#     Values to use for the xticks
#
# yticks : sequence
#     Values to use for the yticks
#
# xlim : 2-tuple/list
#
# ylim : 2-tuple/list
#
# rot : int, default None
#     Rotation for ticks (xticks for vertical, yticks for horizontal plots)
#
# fontsize : int, default None
#     Font size for xticks and yticks
#
# colormap : str or matplotlib colormap object, default None
#     Colormap to select colors from. If string, load colormap with that name
#     from matplotlib.
#
# colorbar : boolean, optional
#     If True, plot colorbar (only relevant for 'scatter' and 'hexbin' plots)
# position : float
#     Specify relative alignments for bar plot layout.
#     From 0 (left/bottom-end) to 1 (right/top-end). Default is 0.5 (center)
#
# table : boolean, Series or DataFrame, default False
#     If True, draw a table using the data in the DataFrame and the data will
#     be transposed to meet matplotlib's default layout.
#     If a Series or DataFrame is passed, use passed data to draw a table.
#
# yerr : DataFrame, Series, array-like, dict and str
#     See :ref:`Plotting with Error Bars <visualization.errorbars>` for
#     detail.
#
# xerr : same types as yerr.
#
# stacked : boolean, default False in line and
#     bar plots, and True in area plot. If True, create stacked plot.
#
# sort_columns : boolean, default False
#     Sort column names to determine plot ordering
#
# secondary_y : boolean or sequence, default False
#     Whether to plot on the secondary y-axis
#     If a list/tuple, which columns to plot on secondary y-axis
#
# mark_right : boolean, default True
#     When using a secondary_y axis, automatically mark the column
#     labels with "(right)" in the legend
#
# `**kwds` : keywords
#     Options to pass to matplotlib plotting method
#
# Returns
# -------
# axes : :class:`matplotlib.axes.Axes` or numpy.ndarray of them
#
# Notes
# -----
#
# - See matplotlib documentation online for more on this subject
# - If `kind` = 'bar' or 'barh', you can specify relative alignments
#   for bar plot layout by `position` keyword.
#   From 0 (left/bottom-end) to 1 (right/top-end). Default is 0.5 (center)
# - If `kind` = 'scatter' and the argument `c` is the name of a dataframe
#   column, the values of that column are used to color each point.
# - If `kind` = 'hexbin', you can control the size of the bins with the
#   `gridsize` argument. By default, a histogram of the counts around each
#   `(x, y)` point is computed. You can specify alternative aggregations
#   by passing values to the `C` and `reduce_C_function` arguments.
#   `C` specifies the value at each `(x, y)` point and `reduce_C_function`
#   is a function of one argument that reduces all the values in a bin to
#   a single number (e.g. `mean`, `max`, `sum`, `std`).

# %%
### Histogram creates bins and plots bar plots of those bins (useful to see entire distributions)

# %%
# KDE (Kernel Desnsity Estimation plot)

# %%
df538
# Out:
#      Rank  Major_code                                          Major  \
# 0       1        2419                          PETROLEUM ENGINEERING
# 1       2        2416                 MINING AND MINERAL ENGINEERING
# 2       3        2415                      METALLURGICAL ENGINEERING
# 3       4        2417      NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4       5        2405                           CHEMICAL ENGINEERING
# 5       6        2418                            NUCLEAR ENGINEERING
# 6       7        6202                              ACTUARIAL SCIENCE
# 7       8        5001                     ASTRONOMY AND ASTROPHYSICS
# 8       9        2414                         MECHANICAL ENGINEERING
# 9      10        2408                         ELECTRICAL ENGINEERING
# 10     11        2407                           COMPUTER ENGINEERING
# 11     12        2401                          AEROSPACE ENGINEERING
# 12     13        2404                         BIOMEDICAL ENGINEERING
# ...

# %%
df538['Median'].hist()

# %% [markdown]
# Outlier at the upper end explains why weighted average was less

# %%
df538['Median'].hist(bins=40)

# %%
df538['Median'].plot.kde()

# %% [markdown]
# Smoothing function to smooth out data

# %% [markdown]
# Pie chart => need categorical data

# %%
df538['Major_category'].value_counts(normalize=True).plot.pie()

# %%
df538['Major_category'].value_counts().plot.bar()

# %%
df538['Major_category'].value_counts().plot.barh()

# %%
df538['Unemployment_rate'].hist(bins=40)

# %%
df538['Unemployed'].hist()

# %%
df538[['ShareWomen','Median']].plot.scatter(x='ShareWomen',y='Median')

# %%
df538[['ShareWomen','Median']].corr()
# Out:
#             ShareWomen   Median
# ShareWomen     1.00000 -0.61869
# Median        -0.61869  1.00000

# %% [markdown]
# Remove outliers by dropping certain observations (can filter out data then plot a new plot)

# %%
df538.sort_values('Median', ascending=False())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-70040c18e527> in <module>()
# ----> 1 df538.sort_values('Median', ascending=False())
#
# TypeError: 'bool' object is not callable

# %%
df538.drop(0)[['ShareWomen','Median']].plot.scatter(x='ShareWomen',y='Median')

# %% [markdown]
# # Lecture 11: Matplotlib Fundamentals 2

# %%
import pandas as pd
# %matplotlib inline

# %%
ghr = pd.read_csv('/Users/hadley/Desktop/Everything/Fall 2018/Data Bootcamp/Greenwich Data/greenwich_master_nyu_2018-10-04.csv', encoding='latin-1',error_bad_lines=False)
# Out:
# b'Skipping line 908145: expected 15 fields, saw 16\n'
# b'Skipping line 6505270: expected 15 fields, saw 16\n'

# %%
ghr
# Out:
#                                    job_id                vertical  \
# 0        20198581751789701529910950958638  Information Technology
# 1         8895868916034283132954081837418  Information Technology
# 2         1519847330480116680516242585467  Information Technology
# 3        92511853348028679647877877985294  Information Technology
# 4          490138684948094100363899533762  Information Technology
# 5        74657902746882254946742123272434  Information Technology
# 6        67959912699822604603156520211049  Information Technology
# 7        62960553541696238196645947323426  Information Technology
# 8        90717759116185198593932094841046  Information Technology
# 9        16387272974132263790431897281915  Information Technology
# 10       72696625716373834009704285573063  Information Technology
# 11        7574193811517788303631671726249  Information Technology
# 12        9522301324327623359690770686252  Information Technology
# ...

# %%
ghr['state'].value_counts()
# Out:
# \N    4018457
# CA     362898
# TX     230602
# VA     212066
# NY     167890
# FL     163781
# IL     134483
# PA     122991
# MD     117125
# NC     114699
# GA     107354
# OH     106245
# MA     103013
# NJ      89857
# CO      88745
# MI      86763
# WA      85003
# AZ      80513
# DC      73201
# MN      70629
# MO      59693
# WI      52025
# TN      48808
# IN      48593
# OR      42800
# SC      37640
# CT      34067
# AL      32808
# UT      30442
# IA      26270
# KY      25091
# KS      24018
# LA      21676
# OK      20699
# NV      19797
# NE      19531
# NM      18854
# NH      16035
# AR      16034
# DE      12210
# HI      10856
# ID      10496
# MS      10218
# RI       9443
# WV       8929
# ME       8279
# ND       6902
# SD       6171
# AK       6004
# MT       5495
# VT       4573
# WY       3421
# PR          6
# Gt          1
# Name: state, dtype: int64

# %%
ghr['state'].value_counts().plot.bar()

# %% [markdown]
# Visualization-- ".plot" method, different types of plots
# There are some options
#
# The other way to create plots is using an unintuitive approach:
#
# Creating two objects: one fig (figure of the plot) and ax (all the details of a plot)

# %%
gdp  = [13271.1, 13773.5, 14234.2, 14613.8, 14873.7, 14830.4, 14418.7,
        14783.8, 15020.6, 15369.2, 15710.3]
pce  = [8867.6, 9208.2, 9531.8, 9821.7, 10041.6, 10007.2, 9847.0, 10036.3,
        10263.5, 10449.7, 10699.7]
year = list(range(2003,2014))        # use range for years 2003-2013

# Note that we set the index
us = pd.DataFrame({'gdp': gdp, 'pce': pce}, index=year)
print(us)
# Out:
#           gdp      pce
# 2003  13271.1   8867.6
# 2004  13773.5   9208.2
# 2005  14234.2   9531.8
# 2006  14613.8   9821.7
# 2007  14873.7  10041.6
# 2008  14830.4  10007.2
# 2009  14418.7   9847.0
# 2010  14783.8  10036.3
# 2011  15020.6  10263.5
# 2012  15369.2  10449.7
# 2013  15710.3  10699.7

# %%
us
# Out:
#           gdp      pce
# 2003  13271.1   8867.6
# 2004  13773.5   9208.2
# 2005  14234.2   9531.8
# 2006  14613.8   9821.7
# 2007  14873.7  10041.6
# 2008  14830.4  10007.2
# 2009  14418.7   9847.0
# 2010  14783.8  10036.3
# 2011  15020.6  10263.5
# 2012  15369.2  10449.7
# 2013  15710.3  10699.7

# %%
us.plot()

# %%
import matplotlib.pyplot as plt

# %%
fig,ax = plt.subplots()#created empty objects from the matplotlib.pyplot package we imported
us.plot(ax=ax, color='turquoise',figsize=(10,5)) #saying all specifications of the plot are stored in ax
ax.set_title('Trends in the US') #Figsize is useful in spreading things out
ax.set_ylabel('Billions of USD')
ax.set_xlabel('Year')
ax.set_ylim(0,20000)
# Out:
# (0, 20000)

# %%
# Important all commands in fig,ax come in the same cell! See above

# %%
type(fig)
# Out:
# matplotlib.figure.Figure

# %%
type(ax)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %% [markdown]
# Have to customize plot in code. Harder in the beginning, but easier to make nice plots in the longrun

# %% [markdown]
# Ax is an option that stores any customization details in this new object.

# %%
gdp  = [13291.1, 13773.5, 14234.2, 14613.8, 14873.7, 14830.4, 14418.7,
        14783.8, 15020.6, 15369.2, 15710.3]
pce  = [8867.6, 9208.2, 9531.8, 9821.7, 10041.6, 10007.2, 9847.0, 10036.3,
        10263.5, 10449.7, 10699.7]
year = list(range(2003,2014))        # use range for years 2003-2013

# Note that we set the index
us2 = pd.DataFrame({'gdp': gdp, 'pce': pce}, index=year)
print(us2)
# Out:
#           gdp      pce
# 2003  13291.1   8867.6
# 2004  13773.5   9208.2
# 2005  14234.2   9531.8
# 2006  14613.8   9821.7
# 2007  14873.7  10041.6
# 2008  14830.4  10007.2
# 2009  14418.7   9847.0
# 2010  14783.8  10036.3
# 2011  15020.6  10263.5
# 2012  15369.2  10449.7
# 2013  15710.3  10699.7

# %% [markdown]
# ### Adding things to graphs

# %%
fig, ax = plt.subplots()

us.plot(ax=ax)
ax.set_title('US GDP and Consumption', fontsize=14, loc='left')
ax.set_ylabel('Billions of 2013 USD')
ax.legend(['GDP', 'Consumption'])           # more descriptive variable names
ax.set_xlim(2002.5, 2013.5)                 # shrink x axis limits
ax.tick_params(labelcolor='red')            # change tick labels to red

# %% [markdown]
# Producing separate subplots

# %%
fig, ax = plt.subplots(nrows=2, ncols=1, sharex=True)
print('Object ax has dimension', len(ax))
# Out:
# Object ax has dimension 2

# %%
fig, ax = plt.subplots(nrows=2, ncols=1, sharex=True)

us['gdp'].plot(ax=ax[0], color='green')   # first plot
us['pce'].plot(ax=ax[1], color='red')     # second plot

# %% [markdown]
# Original Pisa test scores example:

# %%
import pandas as pd
import matplotlib.pyplot as plt

url = 'http://dx.doi.org/10.1787/888932937035'
pisa = pd.read_excel(url,
                     skiprows=18,      # skip the first 18 rows
                     skipfooter=7,     # skip the last 7
                     parse_cols=[0,1,9,13], # select columns of interest
                     index_col=0,      # set the index as the first column
                     header=[0,1]      # set the variable names
                     )
pisa = pisa.dropna()                   # drop blank lines
pisa.columns = ['Math', 'Reading', 'Science'] # simplify variable names

fig, ax = plt.subplots()
pisa['Math'].plot(kind='barh', ax=ax)  # create bar chart
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: FutureWarning: the 'parse_cols' keyword is deprecated, use 'usecols' instead
#   # Remove the CWD from sys.path while we load stuff.

# %%
fig, ax = subplots()
pisa['Math'].plot(kind='barh', ax=ax, figsize=(4,13)) #4 inches wide by 13 inches tall
ax.set_title('PISA Math Score', loc='left')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-62-0ad9ee67aae3> in <module>()
# ----> 1 fig, ax = subplots()
#       2 pisa['Math'].plot(kind='barh', ax=ax, figsize=(4,13))
#       3 ax.set_title('PISA Math Score', loc='left')
#
# TypeError: 'bool' object is not callable

# %%
fig, ax = plt.subplots()
pisa['Math'].plot(ax=ax, kind='barh', figsize=(4,13))
ax.set_title('PISA Math Score', loc='left')
ax.get_children()[36].set_color('r')

# %% [markdown]
# When applying methods, we aren't updating what ax is

# %%
import pandas as pd
import matplotlib.pyplot as plt
url = 'http://dx.doi.org/10.1787/888932937035'
pisa = pd.read_excel(url,
                     skiprows=18,      # skip the first 18 rows
                     skipfooter=7,     # skip the last 7
                     parse_cols=[0,1,9,13], # select columns of interest
                     index_col=0,      # set the index as the first column
                     header=[0,1]      # set the variable names
                     )
pisa = pisa.dropna()                   # drop blank lines
pisa.columns = ['Math', 'Reading', 'Science'] # simplify variable names
fig, ax = plt.subplots()
pisa['Math'].plot(kind='barh', ax=ax,figsize=(4,20), color='blue') # create bar chart
ax.set_title('PISA Math Score', loc='left')
ax.get_children()[36].set_color('r') #Change the color of one item in this data
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: FutureWarning: the 'parse_cols' keyword is deprecated, use 'usecols' instead
#   if __name__ == '__main__':

# %% [markdown]
# Recommendation to learning how to do this well: copy and paste other people's code

# %% [markdown]
# # Lecture 12: Matplotlib 3

# %% [markdown]
# ## Matplotlib Visualizations

# %% [markdown]
# Matplotlib website has a gallery of examples:

# %% [markdown]
# matplotlib.org/gallery.html
#
# https://pandas.pydata.org/pandas-docs/stable/visualization.html

# %% [markdown]
# Dealing with aggregate data usually
#
# Be able to alter the size of data points on a scatterplot to be more representative of weighting

# %% [markdown]
# size option -- s=

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline #Don't forget to add this line

url = 'http://dx.doi.org/10.1787/888932937035'
pisa = pd.read_excel(url,
                     skiprows=18,      # skip the first 18 rows
                     skipfooter=7,     # skip the last 7
                     parse_cols=[0,1,9,13], # select columns of interest
                     index_col=0,      # set the index as the first column
                     header=[0,1]      # set the variable names
                     )
pisa = pisa.dropna()                   # drop blank lines
pisa.columns = ['Math', 'Reading', 'Science'] # simplify variable names

fig, ax = plt.subplots()
pisa['Math'].plot(kind='barh', ax=ax)  # create bar chart
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: FutureWarning: the 'parse_cols' keyword is deprecated, use 'usecols' instead
#   # This is added back by InteractiveShellApp.init_path()

# %%
fig, ax = plt.subplots()
pisa['Math'].plot(kind='barh', ax=ax, figsize=(4,13))
ax.set_title('PISA Math Score', loc='left')
# Out:
# Text(0,1,'PISA Math Score')

# %%
plt.style.use('seaborn-pastel')
fig, ax = plt.subplots()
pisa['Math'].plot(ax=ax, kind='barh', figsize=(4,13))
ax.set_title('PISA Math Score', loc='left')
ax.get_children()[36]
# ax.set_title('GDP',loc='left', fontsize=14)
ax.set_xlabel('Test Score',fontsize=14)
ax.set_ylabel('Country')
ax.spines['left'].set_position(('outward', 10))
ax.spines['bottom'].set_position(('outward', 10))
# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
# Only show ticks on the left and bottom spines
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.text(650,36, 'US Math is right around the Middle') # horizontalalignment='right')
# Out:
# Text(650,36,'US Math is right around the Middle')

# %%
plt.style.use?

# %%
plt.style.available
# Out:
# ['_classic_test',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10']

# %% [markdown]
# Seaborn
#
# plotly -- became popular a year and a halvf ago
#
# bokeh -- more difficult, but can create interactive plots
#
# d3.js -- javascript, more complicated but can make super customizable interactive plots

# %% [markdown]
# ggplot -- data vizualization plot in r

# %%
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)
# %matplotlib inline

# %%
fig, ax = plt.subplots()
pisa['Math'].plot(ax=ax, kind='barh', figsize=(4,13))
ax.set_title('PISA Math Score', loc='left')
ax.get_children()[36]
# ax.set_title('GDP',loc='left', fontsize=14)
ax.set_xlabel('Test Score',fontsize=14)
ax.set_ylabel('Country')
ax.spines['left'].set_position(('outward', 10))
ax.spines['bottom'].set_position(('outward', 10))
# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
# Only show ticks on the left and bottom spines
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')
ax.text(650,36, 'US Math is right around the Middle') # horizontalalignment='right')
# Out:
# Text(650,36,'US Math is right around the Middle')

# %%
plt.xkcd() #makes it all fun and comic-y
pisa['Math'].plot.hist(bins=20, alpha=.8)

# %% [markdown]
# # Lecture 13: Exam Review

# %% [markdown]
# ### List Comprehensions

# %% [markdown]
# A way to create a list without having to name it and create a new object

# %% [markdown]
# Two ways to create a list:
#
# 1. Manually creating a list
#
# 2. Doing a For-Loop

# %%
numbers = [1, 2, 3, 4, 5]

# %%
numbers2 = []
for i in range (1, 6): # Doesn't include the last element
    numbers2.append(i)

# %%
numbers3 = []
for i in range (1, 6): # Doesn't include the last element
    if i>3:
        numbers2.append(i)

# %%
numbers
# Out:
# [1, 2, 3, 4, 5]

# %%
numbers2
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# List comprehension uses a looping approach:

# %%
numbers3
# Out:
# []

# %%
[i for i in range(1,6) if i>3]
# Out:
# [4, 5]

# %% [markdown]
# Same commands as the looping in numbers2, but it has some advantages:
#
# 1. It is on one line
#
# 2. We don't have to create something called numbers3
#
# Just gets created in real time

# %% [markdown]
# #### Can also add if statements to list comprehensions (see above)

# %% [markdown]
# ### Know how to make a nice plot

# %% [markdown]
# i.e. making a title, know where to look and be able to do that pretty quickly
#
# 45 minutes for the exam

# %% [markdown]
# Open notes, but no messaging each other during the exam

# %% [markdown]
# ### For Loops

# %% [markdown]
# Must have iterable elements (countable) not like floats
#
# Can loop through lists, a range, a strings (discreet number of characters), tuples
#
# CAN'T loop though dictionaries; not ordered elements
# Can save keys of dictionaries as a list and iterate through those

# %%
for this in numbers: #i is the iteration variable
    print(this**2) # the operation
# Out:
# 1
# 4
# 9
# 16
# 25

# %% [markdown]
# ### Won't have to clean data to import it in exam

# %% [markdown]
# ### Methods vs. Attributes

# %% [markdown]
# Methods require parenthesis, attributes don't

# %% [markdown]
# Attributes are inherent features of an object (the characteristics and properties)
#
# Methods, something is processing and happening.

# %% [markdown]
# Methods are functions associated with an object. Functions before object, methods after.
#
# Every object type has its own methods

# %%
st = 'this is the last class before the midterm'

# %%
import pandas as pd
df = pd.DataFrame({"GDP": [5974.7, 10031.0, 14681.1],
                   "CPI": [127.5, 169.3, 217.488],
                   "Year": [1990, 2000, 2010],
                   "Country": ["US", "US", "US"]})
print(df)
# Out:
#        GDP      CPI  Year Country
# 0   5974.7  127.500  1990      US
# 1  10031.0  169.300  2000      US
# 2  14681.1  217.488  2010      US

# %%
st
# Out:
# 'this is the last class before the midterm'

# %%
df
# Out:
#        GDP      CPI  Year Country
# 0   5974.7  127.500  1990      US
# 1  10031.0  169.300  2000      US
# 2  14681.1  217.488  2010      US

# %%
st.replace?

# %%
st.replace('a','aa').replace('s','ssssss').replace(' ','_')+'!!!!!!'
# Out:
# 'thissssss_issssss_the_laasssssst_claassssssssssss_before_the_midterm!!!!!!'

# %% [markdown]
# ### Slice Strings

# %% [markdown]
# Adding spaces between things

# %% [markdown]
# #### Writing Functions

# %%
def better_replace(s,l1,l2):
    s2 = s
    for i in range(len(l1)):
        s2 = s.replace(l1[i],l2[i])
    return(s2)

# %%
better_replace(st,['a','s'],['aa','ss'])
# Out:
# 'thiss iss the lasst classss before the midterm'

# %%
df.max()
# Out:
# GDP        14681.1
# CPI        217.488
# Year          2010
# Country         US
# dtype: object

# %% [markdown]
# This is a series (type of object)
#
# It has an index and some values and it is only one dimension

# %% [markdown]
# Can't take the max() of a non-numerical series

# %%
df.drop('Country',axis=1).max().max()# axis = 1 for columns
df.describe().T['max'] # Transpose to get row to columns
# Two different ways to do the same thing
# Out:
# GDP     14681.100
# CPI       217.488
# Year     2010.000
# Name: max, dtype: float64

# %% [markdown]
# ### Other methods with df

# %% [markdown]
# Value counts

# %%
df # didn't redefine df, so country is still included
# Out:
#        GDP      CPI  Year Country
# 0   5974.7  127.500  1990      US
# 1  10031.0  169.300  2000      US
# 2  14681.1  217.488  2010      US

# %%
df.describe() # Only works on numerical variables
# Out:
#                 GDP         CPI    Year
# count      3.000000    3.000000     3.0
# mean   10228.933333  171.429333  2000.0
# std     4356.573590   45.031773    10.0
# min     5974.700000  127.500000  1990.0
# 25%     8002.850000  148.400000  1995.0
# 50%    10031.000000  169.300000  2000.0
# 75%    12356.050000  193.394000  2005.0
# max    14681.100000  217.488000  2010.0

# %%
df.describe()[7:8]
# Out:
#          GDP      CPI    Year
# max  14681.1  217.488  2010.0

# %% [markdown]
# ### Matplotlib: customizing plots

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
df.plot()

# %%
fig,ax = plt.subplots() #Not an intuitive order, but this is what you have to do
df.plot(ax=ax)
ax.set_title('Macro Trends',fontsize=25)
ax.set_ylabel('Billions')
ax.set_xlabel('Index')
# Out:
# Text(0.5,0,'Index')

# %% [markdown]
# The ax object stores our manipulations and customizations

# %% [markdown]
# Fig is something that has to do with the canvas we are on

# %%
# Everything you do is meant to be read. Unlike excel, Python is really for everyone to be
# read by others. Have to stick with the conventions 'import pandas as pd'

# %% [markdown]
# For some pieces, 0 refers to rows and 1 refers to columns. Not for everything!

# %%
df.sum(1) # Sums up the rows, across the columns
# Out:
# 0     8092.200
# 1    12200.300
# 2    16908.588
# dtype: float64

# %%
df.sum(0) #Sums up down each column
# Out:
# GDP        30686.8
# CPI        514.288
# Year          6000
# Country     USUSUS
# dtype: object

# %%
df.drop('Year',1).sum(1)
# Out:
# 0     6102.200
# 1    10200.300
# 2    14898.588
# dtype: float64

# %% [markdown]
# # Homework 2 Python Fundamentals

# %% [markdown]
# # Data Bootcamp: Code Practice #2

# %% [markdown]
# ### 1. Review. Does this code run without error? If so, what does it produce? If not, explain why.

# %%
x = [1, 2, 3]
y = 'bootcamp'
z = x + y
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-23230fddd1c8> in <module>()
#       1 x = [1, 2, 3]
#       2 y = 'bootcamp'
# ----> 3 z = x + y
#
# TypeError: can only concatenate list (not "str") to list

# %% [markdown]
# This code does not run without error. There is a type error because Python cannot concatenate a string to a list.

# %% [markdown]
# ### 2. Review. For the same x and y in the previous question: What function tells us what type they are? What function tells us how many elements they contain?

# %%
type(x)
# Out:
# list

# %%
type(y)
# Out:
# str

# %%
len(x)
# Out:
# 3

# %%
len(y)
# Out:
# 8

# %% [markdown]
# The Type Function tells us the type of a given object in Python. The Length Function len() gives us the number of elements assigned to a given variable (contained in the list or string as in this example).

# %% [markdown]
# ### 3. What type is each expression? How can you tell?

# %%
type(2)
# Out:
# int

# %%
type('2')
# Out:
# str

# %%
type(2.0)
# Out:
# float

# %%
type("2.0")
# Out:
# str

# %%
type(2>1)
# Out:
# bool

# %%
type('Itamar'>'Chase')
# Out:
# bool

# %%
type([1, 2])
# Out:
# list

# %%
type((1,2))
# Out:
# tuple

# %%
type({1: 'one', 2: 'two'})
# Out:
# dict

# %% [markdown]
# Using the Type function is a sure way to check the types of different objects. In general, integers are numbers without decimals, floats are numbers containing decimals, strings are objects placed in quotations (can be really any character beyond just letters), Boolean are objects whose values are either true or false, lists are elements contained in brackets separated by commas, tuples are comma-separated elements in parentheses, and dictionaries are contained in the curly brackets and are composed of keys and values that those keys map to.

# %% [markdown]
# ### 4. What value does each of these comparisons have?

# %%
1>=0
# Out:
# True

# %%
1 >= 0
# Out:
# True

# %%
1 > 1
# Out:
# False

# %%
1==1
# Out:
# True

# %%
1 == 1.0
# Out:
# True

# %%
'Spencer' == "Spencer"
# Out:
# True

# %%
2**3 > 3**2
# Out:
# False

# %%
1 >= 0 or 1 <= 2
# Out:
# True

# %%
1 >= 0 and 1<= 2
# Out:
# True

# %% [markdown]
# ### 5. Does this code run without error? If so, what does it produce? If not, how would you fix it?

# %%
if 2>1
    print('Yes, 2 is still greater than 1')
# Out:
#   File "<ipython-input-33-a0bf5c01fbc0>", line 1
#     if 2>1
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# This code produces a syntax error because if statements require a colon directly following the if statement in the first line of code to run properly.

# %%
if 2>1:
    print('Yes, 2 is still greater than 1')
# Out:
# Yes, 2 is still greater than 1

# %% [markdown]
# ### 6. What is the result of running this code? Why?

# %%
if True:
    print('on the one hand')
else:
    print('but on the other hand')
# Out:
# on the one hand

# %% [markdown]
# The result of this code is the first statment "on the one hand" because Python runs line by line. In this example, if the first expression is true, then the first command is executed and Python ignores the rest of the conditional statement (the else part in this example). if True is always true, so Python will immediately execute the following command.

# %% [markdown]
# ### What happens if we replace True with False in the first line? What happens if we insert the word not after if in the first line?

# %%
if False:
    print('on the one hand')
else:
    print('but on the other hand')
# Out:
# but on the other hand

# %%
if not True:
    print('on the one hand')
else:
    print('but on the other hand')
# Out:
# but on the other hand

# %% [markdown]
# Similar to the previous example, if False is always false so Python goes to the next line and excutes the command following the else statement. If we add a "not" immediately before True, Python carrys out the same thing as replacing True with False. The "not" inverts an expression-- so for True/False it gives the opposite value.

# %% [markdown]
# ### 7. What is the result of running this code?

# %%
cond = True
if cond:
    x = 'Chase'
else:
    x = 'Dave'
print(x)
# Out:
# Chase

# %% [markdown]
# In this example, True is assigned to the variable "cond." so it is essentially saying "if True: x = 'Chase.' As seen above, if True always yields True and Python executes the following command. Python does not even run through the else statement since this first condition is met.

# %% [markdown]
# ### 8. Suppose we have two lists, x = [1, 2, 3, 4] and y = ['x', 'y', 'z']. Adapt the code below to determine which has more elements:

# %%
x = [1, 2, 3, 4]
y = ['x', 'y', 'z']

# %%
if len(x)>len(y):
    print('x has more')
else:
    print("y has at least as many")
# Out:
# x has more

# %% [markdown]
# ### 9. Explain in words what slicing does.

# %% [markdown]
# In Python, slicing allows you to take a section of a given object without changing the original object. For example, in a list, it could allow you to take only a select number of specific elements from the list. By executing a slice, you are inputting a start and a stop,  so that Python knows which element index number to start with (it is included) and where to stop (this last item isn't included). You can additional include a stride (start:stop:stride) that specifies an interval to proceed through the start:stop range by.

# %% [markdown]
# ### 10. How would you extract ("slice") the first element (the integer 1) from the list x below? The last element? All but the last element?

# %%
x = [1, 2, 3, 4, 5]

# %%
x[0]
# Out:
# 1

# %%
x[-1]
# Out:
# 5

# %%
x[:-1]
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# ### 11. Use slicing to extract each word from

# %%
sentence = 'This is a sentence; please slice it.'

# %%
print(sentence[0:4], sentence[5:7], sentence[8:9], sentence[10:18], sentence[20:26],sentence[27:32],sentence[33:35])
# Out:
# This is a sentence please slice it

# %% [markdown]
# You also could've done each slice in a different cell to get each word separately. I chose to print them all together.

# %% [markdown]
# ### 12. Consider the list

# %%
x = [1, 2, "a", 'b', "fast", 'slow', 3, "Raghu", 'Liuren', 10]

# %% [markdown]
# #### a. How would you slice out the first item? The last item?

# %%
x[0]
# Out:
# 1

# %%
x[-1]
# Out:
# 10

# %% [markdown]
# #### b. How would you slice out the items from 'b' to 3 inclusive?

# %%
x[3:7]
# Out:
# ['b', 'fast', 'slow', 3]

# %% [markdown]
# ### 13. Using the same list x, write a loop that prints every element on a new line.

# %%
for elements in x:
    print(elements)
# Out:
# 1
# 2
# a
# b
# fast
# slow
# 3
# Raghu
# Liuren
# 10

# %% [markdown]
# ### 14. Challenging. Using the same list x, write a loop that prints every element of type str.

# %%
for elements in x:
    if type(elements)== str:
        print(elements)
# Out:
# a
# b
# fast
# slow
# Raghu
# Liuren

# %% [markdown]
# ### 15. Use the help functions in Jupyter to find out what the range function does. How would you describe the range (3,12,2)? Verify by converting to a list with list(range(3,12,2)).

# %% [markdown]
# range (3,12,3) creates an obejct beginning at the three and ending at, not including, twelve, with a step (or increment of 2). So it would give you every other element from 3 to 12 not including 12. The start defaults at 0 if not specified.

# %%
list(range(3,12,2))
# Out:
# [3, 5, 7, 9, 11]

# %% [markdown]
# ### 16. Challenging: Write a loop that sums the integers from zero to thirty that are multiples of 3: 3, 6, etc.

# %%
sum = 0
for x in range(0,31,3):
    sum = sum + x
print(sum)
# Out:
# 165

# %% [markdown]
# ### 17. Define a function pocket_change( ) that takes four integers as inputs (numbers of pennies, nickles, dimes, and quarters in your pocket) and returns a floating point number (their dollar value). Run your program with the input(1, 2, 3, 4). Bonus (optional): Report the value with a dollar sign.

# %%
def pocket_change(p,n,d,q):
    return 0.01*p + 0.05*n + 0.10*d + 0.25*q

# %%
pocket_change(1,2,3,4)
# Out:
# 1.4100000000000001

# %%
'${:,.2f}'.format(1.41000000000000001)
# Out:
# '$1.41'

# %% [markdown]
# This is my best effort on adding a dollar sign. I am not sure how to get it to return without the quotes, as I am pretty sure the value must be a string to include dollar sign.

# %% [markdown]
# ### 18. Challenging: Write a function notsix( ) that takes a list of integers and returns a (shorter) list of only those that do not begin with 6. Test it on the list [1234, 6783, 6, 4321, 9876]

# %%
def notsix(list_1):
    for x in list_1:
        if str(list_1)[0] !=6:
            return(new_list)

# %%
list_1 = [1234, 6783, 6, 4321, 9876]

# %%
notsix(list_1)
# Out:
# [1234, 4321, 9876]

# %% [markdown]
# ### 19. Challenging: Explain what this code does:

# %%
old_list = [1234, 6783, 6, 4321, 9876]
new_list = [x for x in old_list if str(x)[0] !="6"]

# %%
print(new_list)
# Out:
# [1234, 4321, 9876]

# %% [markdown]
# This code takes elements in the old list and if their first element in each string is not equal to 6, it returns them in new_list

# %% [markdown]
# ### 20. Consider python object

# %%
z = {1: 'one', 2: 'two', 3: 'three'}

# %% [markdown]
# #### a. What kind of object is z? What is its length?

# %%
len(z)
# Out:
# 3

# %% [markdown]
# z is a dictionary with a length of 3 since there are 3 key/value pairs.

# %% [markdown]
# #### b. Which components are keys? Which are values?

# %% [markdown]
# The keys are the 1, 2, 3 that are immediately prior to the colons. The 'one', 'two', and 'three' are the values since they are following to and corresponding to each of the numerical keys.

# %% [markdown]
# #### c. How would I get the value associated with the key 2?

# %%
for key, value in z.items():
    if key == 2:
        print(value)
# Out:
# two

# %% [markdown]
# #### d. Use Jupyter's help facilities to figure out what z.keys( ) does. Ditto z. values( ). Try them to verify.

# %%
z.keys()
# Out:
# dict_keys([1, 2, 3])

# %%
z.values()
# Out:
# dict_values(['one', 'two', 'three'])

# %% [markdown]
# z.keys() is a built-in method that provides a set-like object providing a view on the dictionary's keys. z.values() does the same thing for a dictionary's values.

# %% [markdown]
# #### e. What does list (z.keys( )) do?

# %%
list(z.keys())
# Out:
# [1, 2, 3]

# %% [markdown]
# This creates a list of the keys associated with dictionary z.

# %% [markdown]
# #### f. What does list (z.values ( )) do?

# %%
list(z.values())
# Out:
# ['one', 'two', 'three']

# %% [markdown]
# This creates a list of the values associated with dictionary z.

# %% [markdown]
# #### g. What does list (z) do?

# %%
list(z)
# Out:
# [1, 2, 3]

# %% [markdown]
# This creates a list of the keys in dictionary z. It does not include the values associated with each key.

# %% [markdown]
# ### 21. Approximately how long did this assignment take you? Answer this by creating a .csv file and entering the time (in minutes) and posting it to your Github my_first_repository titled time_for_practice2.csv

# %% [markdown]
# 180 minutes

# %% [markdown]
# # Homework 3 Pandas and Graphing

# %% [markdown]
# # Data Bootcamp: Code Practice #3

# %% [markdown]
# ### 1. Enter and run this code in a Jupyter cell to produce the dataframe weo:

# %%
import pandas as pd
data = {'BRA': [13.37, 13.30, 14.34, 15.07, 15.46, 15.98, 16.10],
        'JPN': [33.43, 31.83, 33.71, 34.29, 35.60, 36.79, 37.39],
        'USA': [48.30, 46.91, 48.31, 49.72, 51.41, 52.94, 54.60],
        'Year': [2008, 2009, 2010, 2011, 2012, 2013, 2014]}
weo = pd.DataFrame(data)

# %% [markdown]
# The numbers are GDP per person in thousands of US dollars, 2008 to 2014, variable PPPPC in the IMF's World Economic Outlook database.

# %% [markdown]
# a. Explain the import statement.

# %% [markdown]
# The import statement imports the pandas library to this jupyter notebook to allow you to access the specific functions within this library (which are not built into jupyter notebook)

# %% [markdown]
# b. What type of object is data?

# %%
type(data)
# Out:
# dict

# %% [markdown]
# Data is a dictionary-- with country abbreviations/year as the keys, and the float values corresponding to each country and the integer year values as the values to these keys.

# %% [markdown]
# c. Why does the last line have pd prior to the DataFrame function?

# %% [markdown]
# The last line has pd prior to the DataFrame function to indicate that this dataframe will be constructed in pandas

# %% [markdown]
# d. What type of object is weo?

# %%
type(weo)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Weo is a pandas core frame DataFrame

# %% [markdown]
# e. How many rows does it have? Columns?

# %%
weo
# Out:
#      BRA    JPN    USA  Year
# 0  13.37  33.43  48.30  2008
# 1  13.30  31.83  46.91  2009
# 2  14.34  33.71  48.31  2010
# 3  15.07  34.29  49.72  2011
# 4  15.46  35.60  51.41  2012
# 5  15.98  36.79  52.94  2013
# 6  16.10  37.39  54.60  2014

# %%
weo.shape
# Out:
# (7, 4)

# %% [markdown]
# Weo has 7 rows (including the title row) and 4 columns (not including the index column added when creating the dataframe)

# %% [markdown]
# f. What dtypes are the variables/columns? What does this mean?

# %%
weo.dtypes
# Out:
# BRA     float64
# JPN     float64
# USA     float64
# Year      int64
# dtype: object

# %% [markdown]
# The country GDP values are floats (given that they are decimal numbers) while the year is integers (non-decimal numerical values).

# %% [markdown]
# g. Challenging. What are each of these expressions? What type?

# %% [markdown]
# weo['Year']
#
# weo[['Year']]
#
# weo[[3]]

# %%
weo['Year']
# Out:
# 0    2008
# 1    2009
# 2    2010
# 3    2011
# 4    2012
# 5    2013
# 6    2014
# Name: Year, dtype: int64

# %%
weo['Year'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# weo['Year'] is a series

# %%
weo[['Year']]
# Out:
#    Year
# 0  2008
# 1  2009
# 2  2010
# 3  2011
# 4  2012
# 5  2013
# 6  2014

# %%
type(weo[['Year']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# weo[['Year']] creates a new DataFrame object

# %%
type(weo[[3]])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-124-06a54cc62a30> in <module>()
# ----> 1 type(weo[[3]])
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2680         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2681             # either boolean or fancy integer index
# -> 2682             return self._getitem_array(key)
#    2683         elif isinstance(key, DataFrame):
#    2684             return self._getitem_frame(key)
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2724             return self._take(indexer, axis=0)
#    2725         else:
# -> 2726             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2727             return self._take(indexer, axis=1)
#    2728
#
# ...

# %%
weo[[3]].dtype
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-f609735ba6c0> in <module>()
# ----> 1 weo[[3]].dtype
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2680         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2681             # either boolean or fancy integer index
# -> 2682             return self._getitem_array(key)
#    2683         elif isinstance(key, DataFrame):
#    2684             return self._getitem_frame(key)
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2724             return self._take(indexer, axis=0)
#    2725         else:
# -> 2726             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2727             return self._take(indexer, axis=1)
#    2728
#
# ...

# %% [markdown]
# weo[[3]] is not in the index of weo. Python is unable to call the row of the dataframe.

# %% [markdown]
# h. Challenging. Find and apply a method to convert weo['Year'] to type float. Hint: The method begins with a letter a.

# %%
weo.astype(float)
# Out:
#      BRA    JPN    USA    Year
# 0  13.37  33.43  48.30  2008.0
# 1  13.30  31.83  46.91  2009.0
# 2  14.34  33.71  48.31  2010.0
# 3  15.07  34.29  49.72  2011.0
# 4  15.46  35.60  51.41  2012.0
# 5  15.98  36.79  52.94  2013.0
# 6  16.10  37.39  54.60  2014.0

# %% [markdown]
# i. Describe the result of the statement t = weo.tail(3). What kind of object is t? What does it look like?

# %%
t =weo.tail(3)

# %%
t
# Out:
#      BRA    JPN    USA  Year
# 4  15.46  35.60  51.41  2012
# 5  15.98  36.79  52.94  2013
# 6  16.10  37.39  54.60  2014

# %% [markdown]
# This statement creates a new dataframe with only indexed rows 4 and beyond.

# %% [markdown]
# j. How would you create a new dataframe that consists of the first 4 rows of weo?

# %%
t2 = weo.head(5)

# %%
t2
# Out:
#      BRA    JPN    USA  Year
# 0  13.37  33.43  48.30  2008
# 1  13.30  31.83  46.91  2009
# 2  14.34  33.71  48.31  2010
# 3  15.07  34.29  49.72  2011
# 4  15.46  35.60  51.41  2012

# %% [markdown]
# k. What type of object is weo ['BRA']?

# %%
weo['BRA'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# weo['BRA'] is a float

# %% [markdown]
# l. Create a new variable equal to the ratio of Brazil's GDP per capita to Japan's and add it to the ataFrame.

# %%
weo['Ratio']=weo.BRA/weo.JPN

# %%
weo
# Out:
#      BRA    JPN    USA  Year     Ratio
# 0  13.37  33.43  48.30  2008  0.399940
# 1  13.30  31.83  46.91  2009  0.417845
# 2  14.34  33.71  48.31  2010  0.425393
# 3  15.07  34.29  49.72  2011  0.439487
# 4  15.46  35.60  51.41  2012  0.434270
# 5  15.98  36.79  52.94  2013  0.434357
# 6  16.10  37.39  54.60  2014  0.430596

# %% [markdown]
# m. Challenging. Use the drop() method to eliminate this (new) variable from the dataframe.

# %%
weo.drop(['Ratio'], axis = 1)
# Out:
#      BRA    JPN    USA  Year
# 0  13.37  33.43  48.30  2008
# 1  13.30  31.83  46.91  2009
# 2  14.34  33.71  48.31  2010
# 3  15.07  34.29  49.72  2011
# 4  15.46  35.60  51.41  2012
# 5  15.98  36.79  52.94  2013
# 6  16.10  37.39  54.60  2014

# %% [markdown]
# n. What are weo's row and column labels?

# %% [markdown]
# weo's row labels are just indexes (0 through 6) while weo's column names are country abbreviation for the first 3 columns, and year for the last column.

# %% [markdown]
# o. Set the index equal to the Year variable.

# %%
weo= weo.set_index('Year')

# %%
weo
# Out:
#         BRA    JPN    USA
# Year
# 2008  13.37  33.43  48.30
# 2009  13.30  31.83  46.91
# 2010  14.34  33.71  48.31
# 2011  15.07  34.29  49.72
# 2012  15.46  35.60  51.41
# 2013  15.98  36.79  52.94
# 2014  16.10  37.39  54.60

# %% [markdown]
# p. Change the names of the other variables to Brazil, Japan, and United States.

# %%
weo.columns= ['Brazil','Japan','United States']

# %%
weo
# Out:
#       Brazil  Japan  United States
# Year
# 2008   13.37  33.43          48.30
# 2009   13.30  31.83          46.91
# 2010   14.34  33.71          48.31
# 2011   15.07  34.29          49.72
# 2012   15.46  35.60          51.41
# 2013   15.98  36.79          52.94
# 2014   16.10  37.39          54.60

# %% [markdown]
# q. Export the dataframe to an Excel spreadsheet.

# %%
weo.to_excel('/Users/hadley/Desktop/weo.xlsx')

# %% [markdown]
# r. What method would you use to compute the mean for each country? What are the names?

# %%
weo.describe()
# Out:
#           Brazil      Japan  United States
# count   7.000000   7.000000       7.000000
# mean   14.802857  34.720000      50.312857
# std     1.161704   1.975238       2.783258
# min    13.300000  31.830000      46.910000
# 25%    13.855000  33.570000      48.305000
# 50%    15.070000  34.290000      49.720000
# 75%    15.720000  36.195000      52.175000
# max    16.100000  37.390000      54.600000

# %% [markdown]
# Alternatively:

# %%
weo[['Brazil']].mean()
# Out:
# Brazil    14.802857
# dtype: float64

# %%
weo[['Japan']].mean()
# Out:
# Japan    34.72
# dtype: float64

# %%
weo[['United States']].mean()
# Out:
# United States    50.312857
# dtype: float64

# %% [markdown]
# You must use the full country name since we have updated weo to the full names instead of the abbreviations.

# %% [markdown]
# s. Challenging. How would you compute means across countries for each year?

# %%
weo.T.describe()
# Out:
# Year        2008       2009       2010       2011       2012       2013  \
# count   3.000000   3.000000   3.000000   3.000000   3.000000   3.000000
# mean   31.700000  30.680000  32.120000  33.026667  34.156667  35.236667
# std    17.529144  16.834485  17.040725  17.359511  18.018408  18.528897
# min    13.370000  13.300000  14.340000  15.070000  15.460000  15.980000
# 25%    23.400000  22.565000  24.025000  24.680000  25.530000  26.385000
# 50%    33.430000  31.830000  33.710000  34.290000  35.600000  36.790000
# 75%    40.865000  39.370000  41.010000  42.005000  43.505000  44.865000
# max    48.300000  46.910000  48.310000  49.720000  51.410000  52.940000
#
# Year        2014
# count   3.000000
# mean   36.030000
# std    19.285998
# min    16.100000
# 25%    26.745000
# 50%    37.390000
# 75%    45.995000
# max    54.600000

# %% [markdown]
# Looking at the mean line of this transposed dataframe, we have the averages across countries for each year.

# %% [markdown]
# t. Plot the data by applying a plot method to weo.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
weo.plot()

# %% [markdown]
# u. Challenging. Change the color of the lines to green (Brazil), red (Japan), and blue (US).

# %%
fig, ax = plt.subplots()
weo.plot(ax=ax, kind='line', color=['green','red','blue'])

# %% [markdown]
# v. Challenging. Do the same plot with a log scale. Hint: Read the documentation for the plot method.

# %%
fig, ax = plt.subplots()
weo.plot(ax=ax, kind='line', color=['green','red','blue'],logy=True)

# %% [markdown]
# w. Plot Brazil on its own.

# %%
fig, ax = plt.subplots()
weo['Brazil'].plot(ax=ax, kind='line', color=['green'])

# %% [markdown]
# ### 2. Use read_csv( ) to read the responses of a previous semesters entry poll from

# %% [markdown]
# https://raw.githubusercontent.com/NYUDataBootcamp/Materials/master/Data/entry_poll_fall16.csv

# %% [markdown]
# a. Read the file and assign it to the variable ep.

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/NYUDataBootcamp/Materials/master/Data/entry_poll_fall16.csv'
ep = pd.read_csv(url)

print(ep)
# Out:
#               TimeStamp            Why have you enrolled in this course?    \
# 0   2016-08-16 12:55:02                             To help with my career
# 1   2016-08-31 05:54:00                                 I heard it was fun
# 2   2016-09-01 19:43:56                                 I like a challenge
# 3   2016-09-01 20:00:08                                 I heard it was fun
# 4   2016-09-01 20:00:52                                 I heard it was fun
# 5   2016-09-01 20:56:31                                 I heard it was fun
# 6   2016-09-01 22:30:33                             To help with my career
# 7   2016-09-01 22:31:14                             To help with my career
# 8   2016-09-02 01:09:15                        I lost my mind for a minute
# 9   2016-09-02 10:25:48                                 I heard it was fun
# 10  2016-09-02 11:54:33                             To help with my career
# ...

# %%
ep
# Out:
#               TimeStamp            Why have you enrolled in this course?    \
# 0   2016-08-16 12:55:02                             To help with my career
# 1   2016-08-31 05:54:00                                 I heard it was fun
# 2   2016-09-01 19:43:56                                 I like a challenge
# 3   2016-09-01 20:00:08                                 I heard it was fun
# 4   2016-09-01 20:00:52                                 I heard it was fun
# 5   2016-09-01 20:56:31                                 I heard it was fun
# 6   2016-09-01 22:30:33                             To help with my career
# 7   2016-09-01 22:31:14                             To help with my career
# 8   2016-09-02 01:09:15                        I lost my mind for a minute
# 9   2016-09-02 10:25:48                                 I heard it was fun
# 10  2016-09-02 11:54:33                             To help with my career
# ...

# %% [markdown]
# b. Describe its contents. What are the variables? The responses?

# %% [markdown]
# This is a survey of students about the course. The variables are the questions comprising the column titles (individually they are all strings). The responses are the answers given by individual students (also strings).

# %% [markdown]
# c. What data types are the variables?

# %%
ep.dtypes
# Out:
# TimeStamp                                                                                              object
# Why have you enrolled in this course?                                                                  object
# What program are you enrolled in?                                                                      object
# How much programming experience have you had?                                                          object
# How much experience with probability and statistics have you had?                                      object
# What is your expected major or concentration?                                                          object
# What career path most interests you?                                                                   object
# Do you use social media for information purposes?  Check all that apply.                               object
# ...

# %% [markdown]
# All questions are strings. But because these questions are in the data frame format, Pandas interprets them as just objects.

# %% [markdown]
# d. Change the variable names to something shorter.

# %%
ep.columns= ['Time','Reason','Program','Programming Experience','Prob/Stat Experience','Major','Career Interests','Social Media purpose','Data Interest','Topic Interests']

# %%
ep
# Out:
#                    Time                                             Reason  \
# 0   2016-08-16 12:55:02                             To help with my career
# 1   2016-08-31 05:54:00                                 I heard it was fun
# 2   2016-09-01 19:43:56                                 I like a challenge
# 3   2016-09-01 20:00:08                                 I heard it was fun
# 4   2016-09-01 20:00:52                                 I heard it was fun
# 5   2016-09-01 20:56:31                                 I heard it was fun
# 6   2016-09-01 22:30:33                             To help with my career
# 7   2016-09-01 22:31:14                             To help with my career
# 8   2016-09-02 01:09:15                        I lost my mind for a minute
# 9   2016-09-02 10:25:48                                 I heard it was fun
# 10  2016-09-02 11:54:33                             To help with my career
# ...

# %% [markdown]
# e. Challenging. Describe what this code does:

# %%
ep[list(ep)[1]].value_counts()
# Out:
# To help with my career                               60
# I heard it was fun                                   14
# I lost my mind for a minute                           5
# Recommended by a professor.                           1
# I code/build websites in my spare time as a hobby     1
# To finish my major                                    1
# I like a challenge                                    1
# Wanted to try something completely different          1
# i am living in Santiago de Chile                      1
# Name: Reason, dtype: int64

# %% [markdown]
# This code counts the number of responses for the question in column 1 (asking the reasons for taking the class since column 0 is the submission time). It does this by creating an iterable list from the data in dataframe ep.
#
# list(ep) returns all column names. list(ep)[1] returns just the column with index number of 1. Adding ep in front of list(ep)[1] creates a series for which the value_counts is a method which can be performed.

# %% [markdown]
# Suggestion: Break it into two or more statements and explain them one at a time.

# %% [markdown]
# ### 3. Consider the 538 college majors data at url:

# %%
url1 = 'https://raw.githubusercontent.com/fivethirtyeight/data/master/'
url2 = 'college-majors/recent-grads.csv'
url = url1 + url2

# %%
url
# Out:
# 'https://raw.githubusercontent.com/fivethirtyeight/data/master/college-majors/recent-grads.csv'

# %% [markdown]
# The variables are described at:
# https://github.com/fivethirtyeight/data/tree/master/college-majors

# %% [markdown]
# a. Create a dataframe df538 from the csv file at url using read_csv(). What are its dimensions?

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/fivethirtyeight/data/master/college-majors/recent-grads.csv'
df538 = pd.read_csv(url)

print(df538)
# Out:
#      Rank  Major_code                                          Major  \
# 0       1        2419                          PETROLEUM ENGINEERING
# 1       2        2416                 MINING AND MINERAL ENGINEERING
# 2       3        2415                      METALLURGICAL ENGINEERING
# 3       4        2417      NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4       5        2405                           CHEMICAL ENGINEERING
# 5       6        2418                            NUCLEAR ENGINEERING
# 6       7        6202                              ACTUARIAL SCIENCE
# 7       8        5001                     ASTRONOMY AND ASTROPHYSICS
# 8       9        2414                         MECHANICAL ENGINEERING
# 9      10        2408                         ELECTRICAL ENGINEERING
# 10     11        2407                           COMPUTER ENGINEERING
# 11     12        2401                          AEROSPACE ENGINEERING
# 12     13        2404                         BIOMEDICAL ENGINEERING
# ...

# %%
df538
# Out:
#      Rank  Major_code                                          Major  \
# 0       1        2419                          PETROLEUM ENGINEERING
# 1       2        2416                 MINING AND MINERAL ENGINEERING
# 2       3        2415                      METALLURGICAL ENGINEERING
# 3       4        2417      NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4       5        2405                           CHEMICAL ENGINEERING
# 5       6        2418                            NUCLEAR ENGINEERING
# 6       7        6202                              ACTUARIAL SCIENCE
# 7       8        5001                     ASTRONOMY AND ASTROPHYSICS
# 8       9        2414                         MECHANICAL ENGINEERING
# 9      10        2408                         ELECTRICAL ENGINEERING
# 10     11        2407                           COMPUTER ENGINEERING
# 11     12        2401                          AEROSPACE ENGINEERING
# 12     13        2404                         BIOMEDICAL ENGINEERING
# ...

# %% [markdown]
# b. What argument/parameter would you use to read only the first ten lines of the file?

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/fivethirtyeight/data/master/college-majors/recent-grads.csv'
df538_2 = pd.read_csv(url, nrows=10)

# %%
df538_2
# Out:
#    Rank  Major_code                                      Major  Total    Men  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339   2057
# 1     2        2416             MINING AND MINERAL ENGINEERING    756    679
# 2     3        2415                  METALLURGICAL ENGINEERING    856    725
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258   1123
# 4     5        2405                       CHEMICAL ENGINEERING  32260  21239
# 5     6        2418                        NUCLEAR ENGINEERING   2573   2200
# 6     7        6202                          ACTUARIAL SCIENCE   3777   2110
# 7     8        5001                 ASTRONOMY AND ASTROPHYSICS   1792    832
# 8     9        2414                     MECHANICAL ENGINEERING  91227  80320
# 9    10        2408                     ELECTRICAL ENGINEERING  81527  65511
#
#    Women     Major_category  ShareWomen  Sample_size  Employed      ...        \
# ...

# %% [markdown]
# Alternatively, if you want to just take the first 10 rows from an already imported dataframe:

# %%
df538.head(10)
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
# 5     6        2418                        NUCLEAR ENGINEERING   2573.0
# 6     7        6202                          ACTUARIAL SCIENCE   3777.0
# 7     8        5001                 ASTRONOMY AND ASTROPHYSICS   1792.0
# 8     9        2414                     MECHANICAL ENGINEERING  91227.0
# 9    10        2408                     ELECTRICAL ENGINEERING  81527.0
#
#        Men    Women     Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0        Engineering    0.120564           36      1976
# ...

# %% [markdown]
# c. Extract the variables numbered [2, 4, 15, 16, 17]. What are the names of these variables? What do they represent?

# %%
df538.columns
# Out:
# Index(['Rank', 'Major_code', 'Major', 'Total', 'Men', 'Women',
#        'Major_category', 'ShareWomen', 'Sample_size', 'Employed', 'Full_time',
#        'Part_time', 'Full_time_year_round', 'Unemployed', 'Unemployment_rate',
#        'Median', 'P25th', 'P75th', 'College_jobs', 'Non_college_jobs',
#        'Low_wage_jobs'],
#       dtype='object')

# %%
print(list(df538)[2])
print(list(df538)[4])
print(list(df538)[15])
print(list(df538)[16])
print(list(df538)[17])
# Out:
# Major
# Men
# Median
# P25th
# P75th

# %% [markdown]
# Using the .columns method, we were able to get a list of the variable names. Major, index of 2, represents the actual major being analyzed. Men, index of 4, represents the number of men in that given major. Median, index of 15, is the median salary from people who completed those majors. P25th and P75th, indexes of 16 and 17 respectively, represent the lower and upper quartiles of salaries for these majors.

# %% [markdown]
# d. Set the index equal to Major.

# %%
df538 = df538.set_index('Major')

# %%
df538
# Out:
#                                                Rank  Major_code     Total  \
# Major
# PETROLEUM ENGINEERING                             1        2419    2339.0
# MINING AND MINERAL ENGINEERING                    2        2416     756.0
# METALLURGICAL ENGINEERING                         3        2415     856.0
# NAVAL ARCHITECTURE AND MARINE ENGINEERING         4        2417    1258.0
# CHEMICAL ENGINEERING                              5        2405   32260.0
# NUCLEAR ENGINEERING                               6        2418    2573.0
# ACTUARIAL SCIENCE                                 7        6202    3777.0
# ASTRONOMY AND ASTROPHYSICS                        8        5001    1792.0
# MECHANICAL ENGINEERING                            9        2414   91227.0
# ELECTRICAL ENGINEERING                           10        2408   81527.0
# COMPUTER ENGINEERING                             11        2407   41542.0
# AEROSPACE ENGINEERING                            12        2401   15058.0
# ...

# %% [markdown]
# e. Use the sort_values() method to sort the data by Total.

# %%
df538.sort_values('Total')
# Out:
#                                                     Rank  Major_code  \
# Major
# MILITARY TECHNOLOGIES                                 74        3801
# MATHEMATICS AND COMPUTER SCIENCE                      53        4005
# SOIL SCIENCE                                         113        1106
# GEOLOGICAL AND GEOPHYSICAL ENGINEERING                34        2411
# MINING AND MINERAL ENGINEERING                         2        2416
# EDUCATIONAL ADMINISTRATION AND SUPERVISION           121        2301
# SCHOOL STUDENT COUNSELING                             56        2303
# METALLURGICAL ENGINEERING                              3        2415
# LIBRARY SCIENCE                                      173        3501
# COURT REPORTING                                       20        3201
# NAVAL ARCHITECTURE AND MARINE ENGINEERING              4        2417
# BOTANY                                                84        3602
# ...

# %% [markdown]
# f. What code would you use to extract the ten majors with the greatest number of people?

# %%
df538.sort_values('Total',ascending=False).head(10)
# Out:
#                                         Rank  Major_code     Total       Men  \
# Major
# PSYCHOLOGY                               146        5200  393735.0   86648.0
# BUSINESS MANAGEMENT AND ADMINISTRATION    77        6203  329927.0  173809.0
# BIOLOGY                                  124        3600  280709.0  111762.0
# GENERAL BUSINESS                          58        6200  234590.0  132238.0
# COMMUNICATIONS                            94        1901  213996.0   70619.0
# NURSING                                   35        6107  209394.0   21773.0
# MARKETING AND MARKETING RESEARCH          78        6206  205211.0   78857.0
# ACCOUNTING                                41        6201  198633.0   94519.0
# ENGLISH LANGUAGE AND LITERATURE          138        3301  194673.0   58227.0
# POLITICAL SCIENCE AND GOVERNMENT          79        5506  182621.0   93880.0
#
#                                            Women               Major_category  \
# Major
# ...

# %% [markdown]
# g. Challenging. Construct horizontal bar charts of the top ten majors sorted, first, by median salary and, second, by the salary of the 25th percentile. In each case plot just the variable you sorted on.

# %%
df538.sort_values('Median',ascending=False).head(10)
# Out:
#                                            Rank  Major_code    Total      Men  \
# Major
# PETROLEUM ENGINEERING                         1        2419   2339.0   2057.0
# MINING AND MINERAL ENGINEERING                2        2416    756.0    679.0
# METALLURGICAL ENGINEERING                     3        2415    856.0    725.0
# NAVAL ARCHITECTURE AND MARINE ENGINEERING     4        2417   1258.0   1123.0
# CHEMICAL ENGINEERING                          5        2405  32260.0  21239.0
# NUCLEAR ENGINEERING                           6        2418   2573.0   2200.0
# ACTUARIAL SCIENCE                             7        6202   3777.0   2110.0
# ASTRONOMY AND ASTROPHYSICS                    8        5001   1792.0    832.0
# COMPUTER ENGINEERING                         11        2407  41542.0  33258.0
# MATERIALS SCIENCE                            14        5008   4279.0   2949.0
#
#                                              Women     Major_category  \
# Major
# ...

# %%
fig, ax = plt.subplots()
df538.sort_values('Median',ascending=False).head(10)['Median'].plot(kind='barh', ax=ax)

# %%
fig, ax = plt.subplots()
df538.sort_values('P25th',ascending=False).head(10)['P25th'].plot(kind='barh', ax=ax)
